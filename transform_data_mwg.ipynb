# %% [markdown]
# <a href="https://colab.research.google.com/github/nhatminh-01/mwg/blob/main/transform_data_mwg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import split, when, regexp_replace, regexp_extract, initcap, concat_ws, length, col, lpad
from pyspark.sql.types import StringType
import os
import pandas as pd

# %%
current_dir = os.getcwd()
print(current_dir)
# Out:
# /content

# %%
spark = SparkSession.builder.getOrCreate()
print(spark)
# Out:
# <pyspark.sql.session.SparkSession object at 0x7f564dcd7d30>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
current_dir = '/content/drive/MyDrive/mwg/thegioididong'
#current_dir = '/content/drive/MyDrive/mwg'

# %% [markdown]
# #Function CSV

# %% [markdown]
# **Function Read CSV**

# %%
def read_csv(dir):
    data = spark.read \
        .format('csv') \
        .option('header', 'true') \
        .load(current_dir + dir)

    return data

# %% [markdown]
# Function To CSV

# %%
def to_csv(data, dir):
    data.to_csv(current_dir + dir, index=False)

# %% [markdown]
# # **Smart Phone**

# %% [markdown]
# Brand Mobile Phone

# %%
brand = read_csv('/raw/brand/brand_mobile_phone.csv')

# %%
brand.toPandas()
# Out:
#                                               link  \
# 0  https://www.thegioididong.com/dtdd-apple-iphone
# 1       https://www.thegioididong.com/dtdd-samsung
# 2          https://www.thegioididong.com/dtdd-oppo
# 3        https://www.thegioididong.com/dtdd-xiaomi
# 4          https://www.thegioididong.com/dtdd-vivo
# 5        https://www.thegioididong.com/dtdd-realme
# 6         https://www.thegioididong.com/dtdd-nokia
# 7       https://www.thegioididong.com/dtdd-masstel
# 8          https://www.thegioididong.com/dtdd-itel
# 9        https://www.thegioididong.com/dtdd-mobell
#
#                                            link_logo brand_id
# 0  https://cdn.tgdd.vn/Brand/1/logo-iphone-220x48...       01
# 1  https://cdn.tgdd.vn/Brand/1/samsungnew-220x48-...       02
# 2         https://cdn.tgdd.vn/Brand/1/OPPO42-b_5.jpg       03
# 3  https://cdn.tgdd.vn/Brand/1/logo-xiaomi-220x48...       04
# 4  https://cdn.tgdd.vn/Brand/1/vivo-logo-220-220x...       05
# 5      https://cdn.tgdd.vn/Brand/1/Realme42-b_37.png       06
# 6       https://cdn.tgdd.vn/Brand/1/Nokia42-b_21.jpg       07
# 7      https://cdn.tgdd.vn/Brand/1/Masstel42-b_0.png       08
# 8        https://cdn.tgdd.vn/Brand/1/Itel42-b_54.jpg       09
# 9      https://cdn.tgdd.vn/Brand/1/Mobell42-b_19.jpg       10

# %% [markdown]
#  brand_name

# %% [markdown]
# *   Get brand_name
# *   Transform to initcap: This function capitalizes the first letter of each word in a string

# %%
brand = brand.withColumn('brand_name', initcap(split(brand.link, '-')[1]))
brand.toPandas()
# Out:
#                                               link  \
# 0  https://www.thegioididong.com/dtdd-apple-iphone
# 1       https://www.thegioididong.com/dtdd-samsung
# 2          https://www.thegioididong.com/dtdd-oppo
# 3        https://www.thegioididong.com/dtdd-xiaomi
# 4          https://www.thegioididong.com/dtdd-vivo
# 5        https://www.thegioididong.com/dtdd-realme
# 6         https://www.thegioididong.com/dtdd-nokia
# 7       https://www.thegioididong.com/dtdd-masstel
# 8          https://www.thegioididong.com/dtdd-itel
# 9        https://www.thegioididong.com/dtdd-mobell
#
#                                            link_logo brand_id brand_name
# 0  https://cdn.tgdd.vn/Brand/1/logo-iphone-220x48...       01      Apple
# 1  https://cdn.tgdd.vn/Brand/1/samsungnew-220x48-...       02    Samsung
# 2         https://cdn.tgdd.vn/Brand/1/OPPO42-b_5.jpg       03       Oppo
# 3  https://cdn.tgdd.vn/Brand/1/logo-xiaomi-220x48...       04     Xiaomi
# 4  https://cdn.tgdd.vn/Brand/1/vivo-logo-220-220x...       05       Vivo
# 5      https://cdn.tgdd.vn/Brand/1/Realme42-b_37.png       06     Realme
# 6       https://cdn.tgdd.vn/Brand/1/Nokia42-b_21.jpg       07      Nokia
# 7      https://cdn.tgdd.vn/Brand/1/Masstel42-b_0.png       08    Masstel
# 8        https://cdn.tgdd.vn/Brand/1/Itel42-b_54.jpg       09       Itel
# 9      https://cdn.tgdd.vn/Brand/1/Mobell42-b_19.jpg       10     Mobell

# %%
brand = brand.select('brand_id','brand_name', 'link', 'link_logo')
brand.toPandas()
# Out:
#   brand_id brand_name                                             link  \
# 0       01      Apple  https://www.thegioididong.com/dtdd-apple-iphone
# 1       02    Samsung       https://www.thegioididong.com/dtdd-samsung
# 2       03       Oppo          https://www.thegioididong.com/dtdd-oppo
# 3       04     Xiaomi        https://www.thegioididong.com/dtdd-xiaomi
# 4       05       Vivo          https://www.thegioididong.com/dtdd-vivo
# 5       06     Realme        https://www.thegioididong.com/dtdd-realme
# 6       07      Nokia         https://www.thegioididong.com/dtdd-nokia
# 7       08    Masstel       https://www.thegioididong.com/dtdd-masstel
# 8       09       Itel          https://www.thegioididong.com/dtdd-itel
# 9       10     Mobell        https://www.thegioididong.com/dtdd-mobell
#
#                                            link_logo
# 0  https://cdn.tgdd.vn/Brand/1/logo-iphone-220x48...
# 1  https://cdn.tgdd.vn/Brand/1/samsungnew-220x48-...
# 2         https://cdn.tgdd.vn/Brand/1/OPPO42-b_5.jpg
# 3  https://cdn.tgdd.vn/Brand/1/logo-xiaomi-220x48...
# 4  https://cdn.tgdd.vn/Brand/1/vivo-logo-220-220x...
# 5      https://cdn.tgdd.vn/Brand/1/Realme42-b_37.png
# 6       https://cdn.tgdd.vn/Brand/1/Nokia42-b_21.jpg
# 7      https://cdn.tgdd.vn/Brand/1/Masstel42-b_0.png
# 8        https://cdn.tgdd.vn/Brand/1/Itel42-b_54.jpg
# 9      https://cdn.tgdd.vn/Brand/1/Mobell42-b_19.jpg

# %%
brand = brand.withColumnRenamed("link", "link_brand")
brand.toPandas()
# Out:
#    brand_id brand_name                                         link_brand  \
# 0        01      Apple    https://www.thegioididong.com/adapter-sac-apple
# 1        02    Samsung  https://www.thegioididong.com/adapter-sac-samsung
# 2        03      Anker    https://www.thegioididong.com/adapter-sac-anker
# 3        04    Xmobile  https://www.thegioididong.com/adapter-sac-xmobile
# 4        05        Ava  https://www.thegioididong.com/adapter-sac-ava-...
# 5        06        Ava      https://www.thegioididong.com/adapter-sac-ava
# 6        07       Oppo     https://www.thegioididong.com/adapter-sac-oppo
# 7        08     Belkin   https://www.thegioididong.com/adapter-sac-belkin
# 8        09      Aukey    https://www.thegioididong.com/adapter-sac-aukey
# 9        10      Mbest    https://www.thegioididong.com/adapter-sac-mbest
# 10       11     Mophie   https://www.thegioididong.com/adapter-sac-mophie
# 11       12       Vcom     https://www.thegioididong.com/adapter-sac-vcom
# 12       13    Philips  https://www.thegioididong.com/adapter-sac-philips
# 13       14     Hydrus   https://www.thegioididong.com/adapter-sac-hydrus
# 14       15      Evalu    https://www.thegioididong.com/adapter-sac-evalu
# 15       16      Mazer    https://www.thegioididong.com/adapter-sac-mazer
#
#                                             link_logo
# 0      https://cdn.tgdd.vn/Brand/1/Apple9499-b_28.jpg
# 1   https://cdn.tgdd.vn/Brand/1/samsungnew-220x48-...
# 2      https://cdn.tgdd.vn/Brand/1/Anker9499-b_18.png
# 3    https://cdn.tgdd.vn/Brand/1/Xmobile9499-b_10.jpg
# 4    https://cdn.tgdd.vn/Brand/1/220-48-220x48-11.jpg
# 5        https://cdn.tgdd.vn/Brand/1/AVA9499-b_55.jpg
# 6      https://cdn.tgdd.vn/Brand/1/OPPO-220x48-1.jpeg
# 7     https://cdn.tgdd.vn/Brand/1/Belkin9499-b_39.jpg
# 8      https://cdn.tgdd.vn/Brand/1/AUKEY9499-b_38.png
# 9      https://cdn.tgdd.vn/Brand/1/Mbest9499-b_21.jpg
# 10     https://cdn.tgdd.vn/Brand/1/Mophie9499-b_6.jpg
# 11  https://cdn.tgdd.vn/Brand/1/logovcom-220x48-1.png
# 12   https://cdn.tgdd.vn/Brand/1/Philips9499-b_26.png
# 13  https://cdn.tgdd.vn/Brand/1/hydrus-logo-lon-22...
# 14      https://cdn.tgdd.vn/Brand/1/eValu9499-b_0.jpg
# 15       https://cdn.tgdd.vn/Brand/1/JPG-220x48-5.jpg

# %% [markdown]
# Mobile Phone

# %%
product = read_csv('/raw/product/mobile_phone.csv')

# %%
product.toPandas()
# Out:
#                 product_name current_price        price percent_discount  \
# 0    iPhone 14 Pro Max 128GB   26.990.000₫  29.990.000₫             -10%
# 1        iPhone 14 Pro 128GB   24.990.000₫  27.990.000₫             -10%
# 2            iPhone 14 128GB   19.390.000₫  21.990.000₫             -11%
# 3       iPhone 14 Plus 128GB   21.790.000₫  24.990.000₫             -12%
# 4      iPhone 14 Pro Max 1TB   41.990.000₫  43.990.000₫              -4%
# ..                       ...           ...          ...              ...
# 134         Mobell Rock 4 4G      810.000₫         None             None
# 135           Mobell F309 4G      760.000₫         None             None
# 136           Mobell M539 4G      700.000₫         None             None
# 137           Mobell F209 4G      620.000₫         None             None
# 138           Mobell M239 4G      390.000₫     500.000₫             -22%
#
#     rating                                               link brand_id  \
# 0      320  https://www.thegioididong.com/dtdd/iphone-14-p...        1
# 1      160   https://www.thegioididong.com/dtdd/iphone-14-pro        1
# 2       98       https://www.thegioididong.com/dtdd/iphone-14        1
# 3       88  https://www.thegioididong.com/dtdd/iphone-14-plus        1
# 4       37  https://www.thegioididong.com/dtdd/iphone-14-p...        1
# ..     ...                                                ...      ...
# 134     62   https://www.thegioididong.com/dtdd/mobell-rock-4       10
# 135     34     https://www.thegioididong.com/dtdd/mobell-f309       10
# 136     60     https://www.thegioididong.com/dtdd/mobell-m539       10
# 137     24     https://www.thegioididong.com/dtdd/mobell-f209       10
# 138    118     https://www.thegioididong.com/dtdd/mobell-m239       10
#
#                              series       devices
# 0    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 1    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 2    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 3    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 4    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# ..                              ...           ...
# 134                            None  Mobile Phone
# 135                            None  Mobile Phone
# 136                            None  Mobile Phone
# 137                            None  Mobile Phone
# 138                            None  Mobile Phone
#
# [139 rows x 9 columns]

# %%
product.toPandas()
# Out:
#                 product_name current_price        price percent_discount  \
# 0    iPhone 14 Pro Max 128GB   26.990.000₫  29.990.000₫             -10%
# 1        iPhone 14 Pro 128GB   24.990.000₫  27.990.000₫             -10%
# 2            iPhone 14 128GB   19.390.000₫  21.990.000₫             -11%
# 3       iPhone 14 Plus 128GB   21.790.000₫  24.990.000₫             -12%
# 4      iPhone 14 Pro Max 1TB   41.990.000₫  43.990.000₫              -4%
# ..                       ...           ...          ...              ...
# 134         Mobell Rock 4 4G      810.000₫         None             None
# 135           Mobell F309 4G      760.000₫         None             None
# 136           Mobell M539 4G      700.000₫         None             None
# 137           Mobell F209 4G      620.000₫         None             None
# 138           Mobell M239 4G      390.000₫     500.000₫             -22%
#
#     rating                                               link brand_id  \
# 0      320  https://www.thegioididong.com/dtdd/iphone-14-p...        1
# 1      160   https://www.thegioididong.com/dtdd/iphone-14-pro        1
# 2       98       https://www.thegioididong.com/dtdd/iphone-14        1
# 3       88  https://www.thegioididong.com/dtdd/iphone-14-plus        1
# 4       37  https://www.thegioididong.com/dtdd/iphone-14-p...        1
# ..     ...                                                ...      ...
# 134     62   https://www.thegioididong.com/dtdd/mobell-rock-4       10
# 135     34     https://www.thegioididong.com/dtdd/mobell-f309       10
# 136     60     https://www.thegioididong.com/dtdd/mobell-m539       10
# 137     24     https://www.thegioididong.com/dtdd/mobell-f209       10
# 138    118     https://www.thegioididong.com/dtdd/mobell-m239       10
#
#                              series       devices
# 0    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 1    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 2    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 3    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 4    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# ..                              ...           ...
# 134                            None  Mobile Phone
# 135                            None  Mobile Phone
# 136                            None  Mobile Phone
# 137                            None  Mobile Phone
# 138                            None  Mobile Phone
#
# [139 rows x 9 columns]

# %% [markdown]
# **current_price**

# %% [markdown]
# regex: get number is column current_price, regex will remove not number [^\d+]

# %%
product = product.withColumn(
    'current_price', regexp_replace(product.current_price, r'[^\d+]', '').cast('integer'))
product = product.withColumn("current_price", regexp_replace(product.current_price, r'\..*', ''))
product.toPandas()
# Out:
#                 product_name current_price        price percent_discount  \
# 0    iPhone 14 Pro Max 128GB      26990000  29.990.000₫             -10%
# 1        iPhone 14 Pro 128GB      24990000  27.990.000₫             -10%
# 2            iPhone 14 128GB      19390000  21.990.000₫             -11%
# 3       iPhone 14 Plus 128GB      21790000  24.990.000₫             -12%
# 4      iPhone 14 Pro Max 1TB      41990000  43.990.000₫              -4%
# ..                       ...           ...          ...              ...
# 134         Mobell Rock 4 4G        810000         None             None
# 135           Mobell F309 4G        760000         None             None
# 136           Mobell M539 4G        700000         None             None
# 137           Mobell F209 4G        620000         None             None
# 138           Mobell M239 4G        390000     500.000₫             -22%
#
#     rating                                               link brand_id  \
# 0      320  https://www.thegioididong.com/dtdd/iphone-14-p...        1
# 1      160   https://www.thegioididong.com/dtdd/iphone-14-pro        1
# 2       98       https://www.thegioididong.com/dtdd/iphone-14        1
# 3       88  https://www.thegioididong.com/dtdd/iphone-14-plus        1
# 4       37  https://www.thegioididong.com/dtdd/iphone-14-p...        1
# ..     ...                                                ...      ...
# 134     62   https://www.thegioididong.com/dtdd/mobell-rock-4       10
# 135     34     https://www.thegioididong.com/dtdd/mobell-f309       10
# 136     60     https://www.thegioididong.com/dtdd/mobell-m539       10
# 137     24     https://www.thegioididong.com/dtdd/mobell-f209       10
# 138    118     https://www.thegioididong.com/dtdd/mobell-m239       10
#
#                              series       devices
# 0    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 1    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 2    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 3    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 4    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# ..                              ...           ...
# 134                            None  Mobile Phone
# 135                            None  Mobile Phone
# 136                            None  Mobile Phone
# 137                            None  Mobile Phone
# 138                            None  Mobile Phone
#
# [139 rows x 9 columns]

# %% [markdown]
# **price**
#
#
# *   same as current_price
# *   but price have value NaN
#     - if null: price will = current_price
#     - if not null: will transform

# %%
product = product.withColumn(
    'price', when(product.price.isNull(), product.current_price) \
    .otherwise(regexp_replace(product.price, r'[^\d+]', '')).cast('integer')
)
product = product.withColumn("price", regexp_replace(product.price, r'\..*', ''))

product.toPandas()
# Out:
#                 product_name current_price     price percent_discount rating  \
# 0    iPhone 14 Pro Max 128GB      26990000  29990000             -10%    320
# 1        iPhone 14 Pro 128GB      24990000  27990000             -10%    160
# 2            iPhone 14 128GB      19390000  21990000             -11%     98
# 3       iPhone 14 Plus 128GB      21790000  24990000             -12%     88
# 4      iPhone 14 Pro Max 1TB      41990000  43990000              -4%     37
# ..                       ...           ...       ...              ...    ...
# 134         Mobell Rock 4 4G        810000    810000             None     62
# 135           Mobell F309 4G        760000    760000             None     34
# 136           Mobell M539 4G        700000    700000             None     60
# 137           Mobell F209 4G        620000    620000             None     24
# 138           Mobell M239 4G        390000    500000             -22%    118
#
#                                                   link brand_id  \
# 0    https://www.thegioididong.com/dtdd/iphone-14-p...        1
# 1     https://www.thegioididong.com/dtdd/iphone-14-pro        1
# 2         https://www.thegioididong.com/dtdd/iphone-14        1
# 3    https://www.thegioididong.com/dtdd/iphone-14-plus        1
# 4    https://www.thegioididong.com/dtdd/iphone-14-p...        1
# ..                                                 ...      ...
# 134   https://www.thegioididong.com/dtdd/mobell-rock-4       10
# 135     https://www.thegioididong.com/dtdd/mobell-f309       10
# 136     https://www.thegioididong.com/dtdd/mobell-m539       10
# 137     https://www.thegioididong.com/dtdd/mobell-f209       10
# 138     https://www.thegioididong.com/dtdd/mobell-m239       10
#
#                              series       devices
# 0    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 1    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 2    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 3    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 4    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# ..                              ...           ...
# 134                            None  Mobile Phone
# 135                            None  Mobile Phone
# 136                            None  Mobile Phone
# 137                            None  Mobile Phone
# 138                            None  Mobile Phone
#
# [139 rows x 9 columns]

# %% [markdown]
# **percent_discount**
# - if percent_discount null: will = 0
# - else: will transfrom, get number '\d+'

# %%
product = product.withColumn(
    'percent_discount', when(product.percent_discount.isNull(), 0) \
    .otherwise(regexp_extract(product.percent_discount, '\d+', 0)).cast('integer')
)
product.toPandas()
# Out:
#                 product_name current_price     price  percent_discount rating  \
# 0    iPhone 14 Pro Max 128GB      26990000  29990000                10    320
# 1        iPhone 14 Pro 128GB      24990000  27990000                10    160
# 2            iPhone 14 128GB      19390000  21990000                11     98
# 3       iPhone 14 Plus 128GB      21790000  24990000                12     88
# 4      iPhone 14 Pro Max 1TB      41990000  43990000                 4     37
# ..                       ...           ...       ...               ...    ...
# 134         Mobell Rock 4 4G        810000    810000                 0     62
# 135           Mobell F309 4G        760000    760000                 0     34
# 136           Mobell M539 4G        700000    700000                 0     60
# 137           Mobell F209 4G        620000    620000                 0     24
# 138           Mobell M239 4G        390000    500000                22    118
#
#                                                   link brand_id  \
# 0    https://www.thegioididong.com/dtdd/iphone-14-p...        1
# 1     https://www.thegioididong.com/dtdd/iphone-14-pro        1
# 2         https://www.thegioididong.com/dtdd/iphone-14        1
# 3    https://www.thegioididong.com/dtdd/iphone-14-plus        1
# 4    https://www.thegioididong.com/dtdd/iphone-14-p...        1
# ..                                                 ...      ...
# 134   https://www.thegioididong.com/dtdd/mobell-rock-4       10
# 135     https://www.thegioididong.com/dtdd/mobell-f309       10
# 136     https://www.thegioididong.com/dtdd/mobell-m539       10
# 137     https://www.thegioididong.com/dtdd/mobell-f209       10
# 138     https://www.thegioididong.com/dtdd/mobell-m239       10
#
#                              series       devices
# 0    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 1    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 2    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 3    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 4    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# ..                              ...           ...
# 134                            None  Mobile Phone
# 135                            None  Mobile Phone
# 136                            None  Mobile Phone
# 137                            None  Mobile Phone
# 138                            None  Mobile Phone
#
# [139 rows x 9 columns]

# %% [markdown]
# **rating**
# - if null: fill 0
# - else: not change

# %%
product = product.withColumn(
    'rating', when(product.rating.isNull(), 0) \
    .otherwise(product.rating).cast('integer')
)
product.toPandas()
# Out:
#                 product_name current_price     price  percent_discount  \
# 0    iPhone 14 Pro Max 128GB      26990000  29990000                10
# 1        iPhone 14 Pro 128GB      24990000  27990000                10
# 2            iPhone 14 128GB      19390000  21990000                11
# 3       iPhone 14 Plus 128GB      21790000  24990000                12
# 4      iPhone 14 Pro Max 1TB      41990000  43990000                 4
# ..                       ...           ...       ...               ...
# 134         Mobell Rock 4 4G        810000    810000                 0
# 135           Mobell F309 4G        760000    760000                 0
# 136           Mobell M539 4G        700000    700000                 0
# 137           Mobell F209 4G        620000    620000                 0
# 138           Mobell M239 4G        390000    500000                22
#
#      rating                                               link brand_id  \
# 0       320  https://www.thegioididong.com/dtdd/iphone-14-p...        1
# 1       160   https://www.thegioididong.com/dtdd/iphone-14-pro        1
# 2        98       https://www.thegioididong.com/dtdd/iphone-14        1
# 3        88  https://www.thegioididong.com/dtdd/iphone-14-plus        1
# 4        37  https://www.thegioididong.com/dtdd/iphone-14-p...        1
# ..      ...                                                ...      ...
# 134      62   https://www.thegioididong.com/dtdd/mobell-rock-4       10
# 135      34     https://www.thegioididong.com/dtdd/mobell-f309       10
# 136      60     https://www.thegioididong.com/dtdd/mobell-m539       10
# 137      24     https://www.thegioididong.com/dtdd/mobell-f209       10
# 138     118     https://www.thegioididong.com/dtdd/mobell-m239       10
#
#                              series       devices
# 0    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 1    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 2    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 3    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# 4    iPhone 14 (Plus, Pro, Pro Max)  Mobile Phone
# ..                              ...           ...
# 134                            None  Mobile Phone
# 135                            None  Mobile Phone
# 136                            None  Mobile Phone
# 137                            None  Mobile Phone
# 138                            None  Mobile Phone
#
# [139 rows x 9 columns]

# %%
product.printSchema()
# Out:
# root
#  |-- product_name: string (nullable = true)
#  |-- current_price: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- percent_discount: integer (nullable = true)
#  |-- rating: integer (nullable = true)
#  |-- link: string (nullable = true)
#  |-- brand_id: string (nullable = true)
#  |-- series: string (nullable = true)
#  |-- devices: string (nullable = true)

# %%
merged_data = product.join(brand, on='brand_id', how='left')

# %%
product = merged_data.select('product_name', 'current_price', 'price', 'percent_discount', 'rating', 'series','link', 'devices','brand_name')
product.toPandas()
# Out:
#                 product_name current_price     price  percent_discount  \
# 0    iPhone 14 Pro Max 128GB      26990000  29990000                10
# 1        iPhone 14 Pro 128GB      24990000  27990000                10
# 2            iPhone 14 128GB      19390000  21990000                11
# 3       iPhone 14 Plus 128GB      21790000  24990000                12
# 4      iPhone 14 Pro Max 1TB      41990000  43990000                 4
# ..                       ...           ...       ...               ...
# 134         Mobell Rock 4 4G        810000    810000                 0
# 135           Mobell F309 4G        760000    760000                 0
# 136           Mobell M539 4G        700000    700000                 0
# 137           Mobell F209 4G        620000    620000                 0
# 138           Mobell M239 4G        390000    500000                22
#
#      rating                          series  \
# 0       320  iPhone 14 (Plus, Pro, Pro Max)
# 1       160  iPhone 14 (Plus, Pro, Pro Max)
# 2        98  iPhone 14 (Plus, Pro, Pro Max)
# 3        88  iPhone 14 (Plus, Pro, Pro Max)
# 4        37  iPhone 14 (Plus, Pro, Pro Max)
# ..      ...                             ...
# 134      62                            None
# 135      34                            None
# 136      60                            None
# 137      24                            None
# 138     118                            None
#
#                                                   link     devices brand_name
# 0    https://www.thegioididong.com/dtdd/iphone-14-p...  Smartphone      Apple
# 1     https://www.thegioididong.com/dtdd/iphone-14-pro  Smartphone      Apple
# 2         https://www.thegioididong.com/dtdd/iphone-14  Smartphone      Apple
# 3    https://www.thegioididong.com/dtdd/iphone-14-plus  Smartphone      Apple
# 4    https://www.thegioididong.com/dtdd/iphone-14-p...  Smartphone      Apple
# ..                                                 ...         ...        ...
# 134   https://www.thegioididong.com/dtdd/mobell-rock-4  Smartphone     Mobell
# 135     https://www.thegioididong.com/dtdd/mobell-f309  Smartphone     Mobell
# 136     https://www.thegioididong.com/dtdd/mobell-m539  Smartphone     Mobell
# 137     https://www.thegioididong.com/dtdd/mobell-f209  Smartphone     Mobell
# 138     https://www.thegioididong.com/dtdd/mobell-m239  Smartphone     Mobell
#
# [139 rows x 9 columns]

# %%
product = product.filter(col("price").isNotNull())

# %%
brand = brand.select('brand_name')
brand.toPandas()
# Out:
#   brand_name
# 0      Apple
# 1    Samsung
# 2       Oppo
# 3     Xiaomi
# 4       Vivo
# 5     Realme
# 6      Nokia
# 7    Masstel
# 8       Itel
# 9     Mobell

# %%
df = brand.toPandas()
output_path = '/content/drive/MyDrive/thegioididong/transformed/brand/mobile_phone.csv'
df.to_csv(output_path, index=False)

# %%
df = product.toPandas()
output_path = '/content/drive/MyDrive/thegioididong/transformed/product/mobile_phone.csv'
df.to_csv(output_path, index=False)

# %% [markdown]
# ## **`Transform Multi Data`**

# %% [markdown]
# Write Function Transform Brand Multi Data

# %%
def check_contains(brand, devices):
    return brand.filter(brand.link.contains(devices)).count() > 0

# %%
def brand_transform(dir_read, dir_to):
    # read csv
    brand = read_csv(dir_read)

    # brand name
    if check_contains(brand, 'adapter-sac') \
       or check_contains(brand, 'sac-dtdd') \
       or check_contains(brand, 'tai-nghe') \
       or check_contains(brand, 'loa-laptop'):
        brand_for_product = brand.withColumn('b_o', initcap(split(brand.link, '-')[2]))
        brand_for_product = brand_for_product.withColumn('b_t', initcap(split(brand_for_product.link, '-')[3]))
        brand_for_product = brand_for_product.withColumn('brand_name', concat_ws(' ', brand_for_product.b_o, brand_for_product.b_t))
    elif check_contains(brand, 'cap-dien-thoai'):
        brand_for_product = brand.withColumn('b_o', initcap(split(brand.link, '-')[3]))
        brand_for_product = brand_for_product.withColumn('b_t', initcap(split(brand_for_product.link, '-')[4]))
        brand_for_product = brand_for_product.withColumn('brand_name', concat_ws(' ', brand_for_product.b_o, brand_for_product.b_t))
    elif check_contains(brand, 'laptop') \
         or check_contains(brand, 'dtdd'):
        brand_for_product = brand.withColumn('brand_name', initcap(split(brand.link, '-')[1]))
    elif check_contains(brand, 'may-tinh-bang'):
        brand_for_product = brand.withColumn('brand_name', initcap(split(brand.link, '-')[3]))

    else:
        brand_for_product = brand.withColumn('b_o', initcap(split(brand.link, '-')[4]))
        brand_for_product = brand_for_product.withColumn('b_t', initcap(split(brand_for_product.link, '-')[5]))
        brand_for_product = brand_for_product.withColumn('brand_name', concat_ws(' ', brand_for_product.b_o, brand_for_product.b_t))

    brand_for_product = brand_for_product.select('brand_id', 'brand_name', 'link', 'link_logo')

    # select column
    brand = brand_for_product.select('brand_name')

    # to csv brand
    to_csv(brand.toPandas(), dir_to)

    return brand_for_product

# %%
brand_adapter_charger = brand_transform('/raw/brand/brand_adapter_charger.csv', '/transformed/brand/brand_adapter_charger.csv')
brand_backup_charger = brand_transform('/raw/brand/brand_backup_charger.csv', '/transformed/brand/brand_backup_charger.csv')
brand_cables = brand_transform('/raw/brand/brand_cables.csv', '/transformed/brand/brand_cables.csv')
brand_headphone = brand_transform('/raw/brand/brand_headphone.csv', '/transformed/brand/brand_headphone.csv')
brand_laptop_speaker = brand_transform('/raw/brand/brand_laptop_speaker.csv', '/transformed/brand/brand_laptop_speaker.csv')
brand_laptop = brand_transform('/raw/brand/brand_laptop.csv', '/transformed/brand/brand_laptop.csv')
brand_mobile_phone = brand_transform('/raw/brand/brand_mobile_phone.csv', '/transformed/brand/brand_mobile_phone.csv')
brand_smartwatch = brand_transform('/raw/brand/brand_smartwatch.csv', '/transformed/brand/brand_smartwatch.csv')
brand_tablet = brand_transform('/raw/brand/brand_tablet.csv', '/transformed/brand/brand_tablet.csv')

# %% [markdown]
# # **Write Function Transform Product Multi Data**

# %%
def product_tranform(dir_read, dir_to_product, dir_to_brand_d, brand_for_product):
    # read csv
    product = read_csv(dir_read)

    # current price
    product = product.withColumn(
        'current_price', regexp_replace(product.current_price, r'[^\d+]', '').cast('integer')
    )

    # price
    product = product.withColumn(
        'price', when(product.price.isNull(), product.current_price) \
        .otherwise(regexp_replace(product.price, r'[^\d+]', '')).cast('integer')
    )

    # percent discount
    product = product.withColumn(
        'percent_discount', when(product.percent_discount.isNull(), 0) \
        .otherwise(regexp_extract(product.percent_discount, '\d+', 0)).cast('integer')
    )

    # rating
    product = product.withColumn(
        'rating', when(product.rating.isNull(), 0) \
        .otherwise(product.rating).cast('integer')
    )

    # merge brand data
    product = product.withColumn("brand_id", lpad(product["brand_id"], 2, "0"))

    product = product.join(
        brand_for_product.select('brand_id', 'brand_name'), on='brand_id', how='inner'
    )

    # rename
    product = product.withColumnsRenamed({'devices':'genre_name'})

    '''brand details'''
    product_for_brand = brand_for_product.join(
        product.select('brand_id', 'genre_name'), on='brand_id', how='inner'
    )

    product_for_brand = product_for_brand.select('brand_name', 'genre_name', 'link', 'link_logo').distinct()


    # select column
    product = product.withColumnRenamed('devices', 'genre_name')
    product = product.select('product_name', 'current_price', 'price', 'percent_discount', 'rating', 'series', 'link', 'genre_name', 'brand_name')


    # to csv product
    to_csv(product.toPandas(), dir_to_product)

    # to csv brand details
    to_csv(product_for_brand.toPandas(), dir_to_brand_d)

# %%
product_tranform('/raw/product/adapter_charger.csv', '/transformed/product/adapter_charger.csv', '/transformed/brand_details/brand_adapter_charger.csv', brand_adapter_charger)
product_tranform('/raw/product/backup_charger.csv', '/transformed/product/backup_charger.csv', '/transformed/brand_details/brand_backup_charger.csv', brand_backup_charger)
product_tranform('/raw/product/cables.csv', '/transformed/product/cables.csv', '/transformed/brand_details/brand_cables.csv', brand_cables)
product_tranform('/raw/product/headphone.csv', '/transformed/product/headphone.csv', '/transformed/brand_details/brand_headphone.csv', brand_headphone)
product_tranform('/raw/product/laptop_speaker.csv', '/transformed/product/laptop_speaker.csv', '/transformed/brand_details/brand_laptop_speaker.csv', brand_laptop_speaker)
product_tranform('/raw/product/laptop.csv', '/transformed/product/laptop.csv', '/transformed/brand_details/brand_laptop.csv', brand_laptop)
product_tranform('/raw/product/mobile_phone.csv', '/transformed/product/mobile_phone.csv', '/transformed/brand_details/brand_mobile_phone.csv', brand_mobile_phone)
product_tranform('/raw/product/smartwatch.csv', '/transformed/product/smartwatch.csv', '/transformed/brand_details/brand_smartwatch.csv', brand_smartwatch)
product_tranform('/raw/product/tablet.csv', '/transformed/product/tablet.csv', '/transformed/brand_details/brand_tablet.csv', brand_tablet)

# %% [markdown]
# ## Table Brands

# %%
brand_adapter_charger = read_csv('/transformed/brand/brand_adapter_charger.csv')
brand_backup_charger = read_csv('/transformed/brand/brand_backup_charger.csv')
brand_cables = read_csv('/transformed/brand/brand_cables.csv')
brand_headphone = read_csv('/transformed/brand/brand_headphone.csv')
brand_laptop_speaker = read_csv('/transformed/brand/brand_laptop_speaker.csv')
brand_laptop = read_csv('/transformed/brand/brand_laptop.csv')
brand_mobile_phone = read_csv('/transformed/brand/brand_mobile_phone.csv')
brand_smartwatch = read_csv('/transformed/brand/brand_smartwatch.csv')
brand_tablet = read_csv('/transformed/brand/brand_tablet.csv')

# %%
brands = brand_adapter_charger \
         .union(brand_backup_charger) \
         .union(brand_cables) \
         .union(brand_headphone) \
         .union(brand_laptop_speaker) \
         .union(brand_laptop) \
         .union(brand_mobile_phone) \
         .union(brand_smartwatch) \
         .union(brand_tablet) \
         .distinct()

# brands = brands.sort(brands.brand_name.asc())

brands = brands.toPandas()
brands
# Out:
#        brand_name
# 0          Belkin
# 1           Mbest
# 2          Mophie
# 3             Ava
# 4          Hydrus
# ..            ...
# 70           Imoo
# 71        Kidcare
# 72          Befit
# 73          Honor
# 74  Huami Amazfit
#
# [75 rows x 1 columns]

# %%
id = []
for i in range(1, len(brands)+1):
    if i < 10:
        id.append('010' + str(i))
    else:
        id.append('01' + str(i))

brands['brand_id'] = id

# sort column
brands = brands[['brand_id', 'brand_name']]

brands
# Out:
#    brand_id     brand_name
# 0      0101         Belkin
# 1      0102          Mbest
# 2      0103         Mophie
# 3      0104            Ava
# 4      0105         Hydrus
# ..      ...            ...
# 70     0171           Imoo
# 71     0172        Kidcare
# 72     0173          Befit
# 73     0174          Honor
# 74     0175  Huami Amazfit
#
# [75 rows x 2 columns]

# %%
to_csv(brands, '/transformed/brand/brands.csv')

# %%
brands = read_csv('/transformed/brand/brands.csv')
brands.toPandas()
# Out:
#    brand_id     brand_name
# 0      0101         Belkin
# 1      0102          Mbest
# 2      0103         Mophie
# 3      0104            Ava
# 4      0105         Hydrus
# ..      ...            ...
# 70     0171           Imoo
# 71     0172        Kidcare
# 72     0173          Befit
# 73     0174          Honor
# 74     0175  Huami Amazfit
#
# [75 rows x 2 columns]

# %% [markdown]
# **Table Genres**

# %%
genres = pd.DataFrame()

genre = [
    'Adapter Charger',
    'Backup Charger',
    'Cables',
    'Headphone',
    'Laptop Speaker',
    'Laptop',
    'Mobile Phone',
    'SmartWatch',
    'Tablet'
]

id = []
company_id = []
for i in range(1, len(genre)+1):
    if i < 10:
        id.append('010' + str(i))
    else:
        id.append('01' + str(i))
    company_id.append('01')

genres['genre_id'] = id
genres['genre_name'] = genre
genres['company_id'] = company_id

genres
# Out:
#   genre_id       genre_name company_id
# 0     0101  Adapter Charger         01
# 1     0102   Backup Charger         01
# 2     0103           Cables         01
# 3     0104        Headphone         01
# 4     0105   Laptop Speaker         01
# 5     0106           Laptop         01
# 6     0107     Mobile Phone         01
# 7     0108       SmartWatch         01
# 8     0109           Tablet         01

# %%
to_csv(genres, '/transformed/genre/genres.csv')

# %% [markdown]
# Table Brand Details

# %%
brand_adapter_charger = read_csv('/transformed/brand_details/brand_adapter_charger.csv')
brand_backup_charger = read_csv('/transformed/brand_details/brand_backup_charger.csv')
brand_cables = read_csv('/transformed/brand_details/brand_cables.csv')
brand_headphone = read_csv('/transformed/brand_details/brand_headphone.csv')
brand_laptop_speaker = read_csv('/transformed/brand_details/brand_laptop_speaker.csv')
brand_laptop = read_csv('/transformed/brand_details/brand_laptop.csv')
brand_mobile_phone = read_csv('/transformed/brand_details/brand_mobile_phone.csv')
brand_smartwatch = read_csv('/transformed/brand_details/brand_smartwatch.csv')
brand_tablet = read_csv('/transformed/brand_details/brand_tablet.csv')

# %%
genres = read_csv('/transformed/genre/genres.csv')
brands = read_csv('/transformed/brand/brands.csv')

# %%
brand_details = brand_adapter_charger \
                .union(brand_backup_charger) \
                .union(brand_cables) \
                .union(brand_headphone) \
                .union(brand_laptop_speaker) \
                .union(brand_laptop) \
                .union(brand_mobile_phone) \
                .union(brand_smartwatch) \
                .union(brand_tablet) \
                .distinct()

brand_details.toPandas()
# Out:
#     brand_name       genre_name  \
# 0        Evalu  Adapter Charger
# 1        Apple  Adapter Charger
# 2     Ava Plus  Adapter Charger
# 3         Vcom  Adapter Charger
# 4      Xmobile  Adapter Charger
# ..         ...              ...
# 122       Oppo           Tablet
# 123      Apple           Tablet
# 124     Xiaomi           Tablet
# 125    Samsung           Tablet
# 126    Masstel           Tablet
#
#                                                   link  \
# 0      https://www.thegioididong.com/adapter-sac-evalu
# 1      https://www.thegioididong.com/adapter-sac-apple
# 2    https://www.thegioididong.com/adapter-sac-ava-...
# 3       https://www.thegioididong.com/adapter-sac-vcom
# 4    https://www.thegioididong.com/adapter-sac-xmobile
# ..                                                 ...
# 122   https://www.thegioididong.com/may-tinh-bang-oppo
# 123  https://www.thegioididong.com/may-tinh-bang-ap...
# 124  https://www.thegioididong.com/may-tinh-bang-xi...
# 125  https://www.thegioididong.com/may-tinh-bang-sa...
# 126  https://www.thegioididong.com/may-tinh-bang-ma...
#
#                                              link_logo
# 0        https://cdn.tgdd.vn/Brand/1/eValu9499-b_0.jpg
# 1       https://cdn.tgdd.vn/Brand/1/Apple9499-b_28.jpg
# 2     https://cdn.tgdd.vn/Brand/1/220-48-220x48-11.jpg
# 3    https://cdn.tgdd.vn/Brand/1/logovcom-220x48-1.png
# 4     https://cdn.tgdd.vn/Brand/1/Xmobile9499-b_10.jpg
# ..                                                 ...
# 122  https://cdn.tgdd.vn/Brand/1/OPPO-logo-lon-220x...
# 123  https://cdn.tgdd.vn/Brand/1/iPad-(Apple)522-b_...
# 124  https://cdn.tgdd.vn/Brand/1/Tablet-xiaomi-220x...
# 125  https://cdn.tgdd.vn/Brand/1/samsungnew-220x48-...
# 126     https://cdn.tgdd.vn/Brand/1/Masstel522-b_7.png
#
# [127 rows x 4 columns]

# %%
brand_details = brand_details \
                .join(genres, on='genre_name', how='inner') \
                .join(brands, on='brand_name', how='inner')

brand_details = brand_details.toPandas()
brand_details
# Out:
#     brand_name       genre_name  \
# 0        Evalu  Adapter Charger
# 1        Apple  Adapter Charger
# 2     Ava Plus  Adapter Charger
# 3         Vcom  Adapter Charger
# 4      Xmobile  Adapter Charger
# ..         ...              ...
# 122       Oppo           Tablet
# 123      Apple           Tablet
# 124     Xiaomi           Tablet
# 125    Samsung           Tablet
# 126    Masstel           Tablet
#
#                                                   link  \
# 0      https://www.thegioididong.com/adapter-sac-evalu
# 1      https://www.thegioididong.com/adapter-sac-apple
# 2    https://www.thegioididong.com/adapter-sac-ava-...
# 3       https://www.thegioididong.com/adapter-sac-vcom
# 4    https://www.thegioididong.com/adapter-sac-xmobile
# ..                                                 ...
# 122   https://www.thegioididong.com/may-tinh-bang-oppo
# 123  https://www.thegioididong.com/may-tinh-bang-ap...
# 124  https://www.thegioididong.com/may-tinh-bang-xi...
# 125  https://www.thegioididong.com/may-tinh-bang-sa...
# 126  https://www.thegioididong.com/may-tinh-bang-ma...
#
#                                              link_logo genre_id company_id  \
# 0        https://cdn.tgdd.vn/Brand/1/eValu9499-b_0.jpg     0101         01
# 1       https://cdn.tgdd.vn/Brand/1/Apple9499-b_28.jpg     0101         01
# 2     https://cdn.tgdd.vn/Brand/1/220-48-220x48-11.jpg     0101         01
# 3    https://cdn.tgdd.vn/Brand/1/logovcom-220x48-1.png     0101         01
# 4     https://cdn.tgdd.vn/Brand/1/Xmobile9499-b_10.jpg     0101         01
# ..                                                 ...      ...        ...
# 122  https://cdn.tgdd.vn/Brand/1/OPPO-logo-lon-220x...     0109         01
# 123  https://cdn.tgdd.vn/Brand/1/iPad-(Apple)522-b_...     0109         01
# 124  https://cdn.tgdd.vn/Brand/1/Tablet-xiaomi-220x...     0109         01
# 125  https://cdn.tgdd.vn/Brand/1/samsungnew-220x48-...     0109         01
# 126     https://cdn.tgdd.vn/Brand/1/Masstel522-b_7.png     0109         01
#
#     brand_id
# 0       0112
# 1       0115
# 2       0116
# 3       0107
# 4       0114
# ..       ...
# 122     0109
# 123     0115
# 124     0127
# 125     0110
# 126     0158
#
# [127 rows x 7 columns]

# %%
brand_details = brand_details[['brand_id', 'genre_id', 'link', 'link_logo']]

# %%
to_csv(brand_details, '/transformed/brand_details/brand_details.csv')

# %% [markdown]
# Tables Products

# %%
adapter_charger = read_csv('/transformed/product/adapter_charger.csv')
backup_charger = read_csv('/transformed/product/backup_charger.csv')
cables = read_csv('/transformed/product/cables.csv')
headphone = read_csv('/transformed/product/headphone.csv')
laptop_speaker = read_csv('/transformed/product/laptop_speaker.csv')
laptop = read_csv('/transformed/product/laptop.csv')
mobile_phone = read_csv('/transformed/product/mobile_phone.csv')
smartwatch = read_csv('/transformed/product/smartwatch.csv')
tablet = read_csv('/transformed/product/tablet.csv')

# %%
genres = read_csv('/transformed/genre/genres.csv')
brands = read_csv('/transformed/brand/brands.csv')

# %%
products = adapter_charger \
           .union(backup_charger) \
           .union(cables) \
           .union(headphone) \
           .union(laptop_speaker) \
           .union(laptop) \
           .union(mobile_phone) \
           .union(smartwatch) \
           .union(tablet)

products.toPandas()
# Out:
#                                            product_name current_price  \
# 0                                   Sạc Apple 20W MHJE3      520000.0
# 1        Bộ chuyển đổi chân sạc Adapter Kit Apple MD837      980000.0
# 2                                       Sạc Apple MGN13      270000.0
# 3     Bộ Adapter sạc kèm cáp Type C - Type C Samsung...     1070000.0
# 4                                 Sạc Samsung EP-TA800N      390000.0
# ...                                                 ...           ...
# 1059                                 OPPO Pad Air 128GB       7990000
# 1060                                  OPPO Pad Air 64GB       6690000
# 1061                                    Masstel Tab 10S       2690000
# 1062                                    Masstel Tab 10A       2690000
# 1063                                    Masstel Tab 8.2       2390000
#
#           price percent_discount rating series  \
# 0      690000.0               24    436   None
# 1     1090000.0               10      0   None
# 2      450000.0               40     55   None
# 3     1190000.0               10     70   None
# 4      490000.0               20    329   None
# ...         ...              ...    ...    ...
# 1059    7990000                0      9   None
# 1060    6690000                0     53   None
# 1061    2890000                6     93   None
# 1062    2790000                3     41   None
# 1063    2490000                4     43   None
#
#                                                    link       genre_name  \
# 0     https://www.thegioididong.com/adapter-sac/adap...  Adapter Charger
# 1     https://www.thegioididong.com/adapter-sac/chan...  Adapter Charger
# 2     https://www.thegioididong.com/adapter-sac/adap...  Adapter Charger
# 3     https://www.thegioididong.com/adapter-sac/bo-a...  Adapter Charger
# 4     https://www.thegioididong.com/adapter-sac/type...  Adapter Charger
# ...                                                 ...              ...
# 1059  https://www.thegioididong.com/may-tinh-bang/op...           Tablet
# 1060  https://www.thegioididong.com/may-tinh-bang/op...           Tablet
# 1061  https://www.thegioididong.com/may-tinh-bang/ma...           Tablet
# 1062  https://www.thegioididong.com/may-tinh-bang/ma...           Tablet
# 1063  https://www.thegioididong.com/may-tinh-bang/ma...           Tablet
#
#      brand_name
# 0         Apple
# 1         Apple
# 2         Apple
# 3       Samsung
# 4       Samsung
# ...         ...
# 1059       Oppo
# 1060       Oppo
# 1061    Masstel
# 1062    Masstel
# 1063    Masstel
#
# [1064 rows x 9 columns]

# %%
products = products \
           .join(genres, on='genre_name', how='inner') \
           .join(brands, on='brand_name', how='inner')
products = products.toPandas()
products
# Out:
#      brand_name       genre_name  \
# 0         Apple  Adapter Charger
# 1         Apple  Adapter Charger
# 2         Apple  Adapter Charger
# 3       Samsung  Adapter Charger
# 4       Samsung  Adapter Charger
# ...         ...              ...
# 1059       Oppo           Tablet
# 1060       Oppo           Tablet
# 1061    Masstel           Tablet
# 1062    Masstel           Tablet
# 1063    Masstel           Tablet
#
#                                            product_name current_price  \
# 0                                   Sạc Apple 20W MHJE3      520000.0
# 1        Bộ chuyển đổi chân sạc Adapter Kit Apple MD837      980000.0
# 2                                       Sạc Apple MGN13      270000.0
# 3     Bộ Adapter sạc kèm cáp Type C - Type C Samsung...     1070000.0
# 4                                 Sạc Samsung EP-TA800N      390000.0
# ...                                                 ...           ...
# 1059                                 OPPO Pad Air 128GB       7990000
# 1060                                  OPPO Pad Air 64GB       6690000
# 1061                                    Masstel Tab 10S       2690000
# 1062                                    Masstel Tab 10A       2690000
# 1063                                    Masstel Tab 8.2       2390000
#
#           price percent_discount rating series  \
# 0      690000.0               24    436   None
# 1     1090000.0               10      0   None
# 2      450000.0               40     55   None
# 3     1190000.0               10     70   None
# 4      490000.0               20    329   None
# ...         ...              ...    ...    ...
# 1059    7990000                0      9   None
# 1060    6690000                0     53   None
# 1061    2890000                6     93   None
# 1062    2790000                3     41   None
# 1063    2490000                4     43   None
#
#                                                    link genre_id company_id  \
# 0     https://www.thegioididong.com/adapter-sac/adap...     0101         01
# 1     https://www.thegioididong.com/adapter-sac/chan...     0101         01
# 2     https://www.thegioididong.com/adapter-sac/adap...     0101         01
# 3     https://www.thegioididong.com/adapter-sac/bo-a...     0101         01
# 4     https://www.thegioididong.com/adapter-sac/type...     0101         01
# ...                                                 ...      ...        ...
# 1059  https://www.thegioididong.com/may-tinh-bang/op...     0109         01
# 1060  https://www.thegioididong.com/may-tinh-bang/op...     0109         01
# 1061  https://www.thegioididong.com/may-tinh-bang/ma...     0109         01
# 1062  https://www.thegioididong.com/may-tinh-bang/ma...     0109         01
# 1063  https://www.thegioididong.com/may-tinh-bang/ma...     0109         01
#
#      brand_id
# 0        0115
# 1        0115
# 2        0115
# 3        0110
# 4        0110
# ...       ...
# 1059     0109
# 1060     0109
# 1061     0158
# 1062     0158
# 1063     0158
#
# [1064 rows x 12 columns]

# %%
id = []
for i in range(1, len(products)+1):
    if i < 10:
        id.append('01000' + str(i))
    elif i < 100:
        id.append('0100' + str(i))
    elif i < 1000:
        id.append('010' + str(i))
    else:
        id.append('01' + str(i))

products['product_id'] = id

products
# Out:
#      brand_name       genre_name  \
# 0         Apple  Adapter Charger
# 1         Apple  Adapter Charger
# 2         Apple  Adapter Charger
# 3       Samsung  Adapter Charger
# 4       Samsung  Adapter Charger
# ...         ...              ...
# 1059       Oppo           Tablet
# 1060       Oppo           Tablet
# 1061    Masstel           Tablet
# 1062    Masstel           Tablet
# 1063    Masstel           Tablet
#
#                                            product_name current_price  \
# 0                                   Sạc Apple 20W MHJE3      520000.0
# 1        Bộ chuyển đổi chân sạc Adapter Kit Apple MD837      980000.0
# 2                                       Sạc Apple MGN13      270000.0
# 3     Bộ Adapter sạc kèm cáp Type C - Type C Samsung...     1070000.0
# 4                                 Sạc Samsung EP-TA800N      390000.0
# ...                                                 ...           ...
# 1059                                 OPPO Pad Air 128GB       7990000
# 1060                                  OPPO Pad Air 64GB       6690000
# 1061                                    Masstel Tab 10S       2690000
# 1062                                    Masstel Tab 10A       2690000
# 1063                                    Masstel Tab 8.2       2390000
#
#           price percent_discount rating series  \
# 0      690000.0               24    436   None
# 1     1090000.0               10      0   None
# 2      450000.0               40     55   None
# 3     1190000.0               10     70   None
# 4      490000.0               20    329   None
# ...         ...              ...    ...    ...
# 1059    7990000                0      9   None
# 1060    6690000                0     53   None
# 1061    2890000                6     93   None
# 1062    2790000                3     41   None
# 1063    2490000                4     43   None
#
#                                                    link genre_id company_id  \
# 0     https://www.thegioididong.com/adapter-sac/adap...     0101         01
# 1     https://www.thegioididong.com/adapter-sac/chan...     0101         01
# 2     https://www.thegioididong.com/adapter-sac/adap...     0101         01
# 3     https://www.thegioididong.com/adapter-sac/bo-a...     0101         01
# 4     https://www.thegioididong.com/adapter-sac/type...     0101         01
# ...                                                 ...      ...        ...
# 1059  https://www.thegioididong.com/may-tinh-bang/op...     0109         01
# 1060  https://www.thegioididong.com/may-tinh-bang/op...     0109         01
# 1061  https://www.thegioididong.com/may-tinh-bang/ma...     0109         01
# 1062  https://www.thegioididong.com/may-tinh-bang/ma...     0109         01
# 1063  https://www.thegioididong.com/may-tinh-bang/ma...     0109         01
#
#      brand_id product_id
# 0        0115     010001
# 1        0115     010002
# 2        0115     010003
# 3        0110     010004
# 4        0110     010005
# ...       ...        ...
# 1059     0109     011060
# 1060     0109     011061
# 1061     0158     011062
# 1062     0158     011063
# 1063     0158     011064
#
# [1064 rows x 13 columns]

# %%
# select column
products = products[['product_id', 'product_name', 'current_price', 'price', 'percent_discount', 'rating', 'series', 'link', 'brand_id', 'genre_id']]

# %%
to_csv(products, '/transformed/product/products.csv')

# %%
products = read_csv('/transformed/product/products.csv')

# %%
products = products \
           .join(genres, on='genre_id', how='inner') \
           .join(brands, on='brand_id', how='inner')
products.toPandas()
# Out:
#      brand_id genre_id product_id  \
# 0        0115     0101     010001
# 1        0115     0101     010002
# 2        0115     0101     010003
# 3        0110     0101     010004
# 4        0110     0101     010005
# ...       ...      ...        ...
# 1059     0109     0109     011060
# 1060     0109     0109     011061
# 1061     0158     0109     011062
# 1062     0158     0109     011063
# 1063     0158     0109     011064
#
#                                            product_name current_price  \
# 0                                   Sạc Apple 20W MHJE3      520000.0
# 1        Bộ chuyển đổi chân sạc Adapter Kit Apple MD837      980000.0
# 2                                       Sạc Apple MGN13      270000.0
# 3     Bộ Adapter sạc kèm cáp Type C - Type C Samsung...     1070000.0
# 4                                 Sạc Samsung EP-TA800N      390000.0
# ...                                                 ...           ...
# 1059                                 OPPO Pad Air 128GB       7990000
# 1060                                  OPPO Pad Air 64GB       6690000
# 1061                                    Masstel Tab 10S       2690000
# 1062                                    Masstel Tab 10A       2690000
# 1063                                    Masstel Tab 8.2       2390000
#
#           price percent_discount rating series  \
# 0      690000.0               24    436   None
# 1     1090000.0               10      0   None
# 2      450000.0               40     55   None
# 3     1190000.0               10     70   None
# 4      490000.0               20    329   None
# ...         ...              ...    ...    ...
# 1059    7990000                0      9   None
# 1060    6690000                0     53   None
# 1061    2890000                6     93   None
# 1062    2790000                3     41   None
# 1063    2490000                4     43   None
#
#                                                    link       genre_name  \
# 0     https://www.thegioididong.com/adapter-sac/adap...  Adapter Charger
# 1     https://www.thegioididong.com/adapter-sac/chan...  Adapter Charger
# 2     https://www.thegioididong.com/adapter-sac/adap...  Adapter Charger
# 3     https://www.thegioididong.com/adapter-sac/bo-a...  Adapter Charger
# 4     https://www.thegioididong.com/adapter-sac/type...  Adapter Charger
# ...                                                 ...              ...
# 1059  https://www.thegioididong.com/may-tinh-bang/op...           Tablet
# 1060  https://www.thegioididong.com/may-tinh-bang/op...           Tablet
# 1061  https://www.thegioididong.com/may-tinh-bang/ma...           Tablet
# 1062  https://www.thegioididong.com/may-tinh-bang/ma...           Tablet
# 1063  https://www.thegioididong.com/may-tinh-bang/ma...           Tablet
#
#      company_id brand_name
# 0            01      Apple
# 1            01      Apple
# 2            01      Apple
# 3            01    Samsung
# 4            01    Samsung
# ...         ...        ...
# 1059         01       Oppo
# 1060         01       Oppo
# 1061         01    Masstel
# 1062         01    Masstel
# 1063         01    Masstel
#
# [1064 rows x 13 columns]

# %% [markdown]
# # Final Data

# %%
current_dir = '/content/drive/MyDrive/mwg'

# %%
brand_tgdd = read_csv('/thegioididong/transformed/brand/brands.csv')
#brand_dmx = read_csv('/dien_may_xanh/transformed/brand/brands.csv')

# %%
brands = brand_tgdd \
         #.union(brand_dmx)

to_csv(brands.toPandas(), '/brands.csv')

# %%
product_tgdd = read_csv('/thegioididong/transformed/product/products.csv')
#product_dmx = read_csv('/dien_may_xanh/transformed/product/products.csv')

# %%
products = product_tgdd \
          # .union(product_dmx)

to_csv(products.toPandas(), '/products.csv')

# %%
brand_d_tgdd = read_csv('/thegioididong/transformed/brand_details/brand_details.csv')
#brand_d_dmx = read_csv('/dien_may_xanh/transformed/brand_details/brand_details.csv')

# %%
brand_details = brand_d_tgdd \
            #    .union(brand_d_dmx)

to_csv(brand_details.toPandas(), '/brand_details.csv')

# %%
genre_tgdd = read_csv('/thegioididong/transformed/genre/genres.csv')
#genre_dmx = read_csv('/dien_may_xanh/transformed/genre/genres.csv')

# %%
genres = genre_tgdd \
   #      .union(genre_dmx)

to_csv(genres.toPandas(), '/genres.csv')
